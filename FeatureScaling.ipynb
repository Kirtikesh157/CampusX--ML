# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Social_Network_Ads.csv')
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %% [markdown]
# Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased',axis=1), 
                                                     df['Purchased'],
                                                     test_size=0.25, random_state=0)

X_train.shape,X_test.shape
# Out:
# ((300, 2), (100, 2))

# %% [markdown]
# StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()

# fitting the scaler to the training set, it  will  learn the parameters
scaler.fit(X_train)

# transforming train and test  sets
X_train_scaled=scaler.transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.81266667e+01, 6.95833333e+04])

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 250   44            39000
# 63    32           120000
# 312   38            50000
# 159   32           135000
# 283   52            21000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [300 rows x 2 columns]

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  300.0            300.0
# mean    38.1          69583.3
# std     10.1          34548.5
# min     18.0          15000.0
# 25%     30.8          43000.0
# 50%     38.0          69500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
X_train_scaled
# Out:
# array([[ 0.58164944, -0.88670699],
#        [-0.60673761,  1.46173768],
#        [-0.01254409, -0.5677824 ],
#        [-0.60673761,  1.89663484],
#        [ 1.37390747, -1.40858358],
#        [ 1.47293972,  0.99784738],
#        [ 0.08648817, -0.79972756],
#        [-0.01254409, -0.24885782],
#        [-0.21060859, -0.5677824 ],
#        [-0.21060859, -0.19087153],
#        [-0.30964085, -1.29261101],
#        [-0.30964085, -0.5677824 ],
#        [ 0.38358493,  0.09905991],
#        [ 0.8787462 , -0.59677555],
#        [ 2.06713324, -1.17663843],
#        [ 1.07681071, -0.13288524],
#        [ 0.68068169,  1.78066227],
#        [-0.70576986,  0.56295021],
#        [ 0.77971394,  0.35999821],
#        [ 0.8787462 , -0.53878926],
#        [-1.20093113, -1.58254245],
#        [ 2.1661655 ,  0.93986109],
#        [-0.01254409,  1.22979253],
#        [ 0.18552042,  1.08482681],
#        [ 0.38358493, -0.48080297],
#        [-0.30964085, -0.30684411],
#        [ 0.97777845, -0.8287207 ],
# ...

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  300.0            300.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -2.0             -1.6
# 25%     -0.7             -0.8
# 50%     -0.0             -0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %% [markdown]
# Effect osf scaling

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.scatter(X_train['Age'],X_train['EstimatedSalary'])
ax1.set_title('Before scaling')
ax2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title('After scaling')

plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))


#  befor  scaling  
ax1.set_title("Before Scaling")
sns.kdeplot(x=X_train['Age'], ax=ax1, label='Age')
sns.kdeplot(x=X_train['EstimatedSalary'], ax=ax1, label='EstimatedSalary')
ax1.legend()


# after scaling
ax2.set_title("After Scaling")
sns.kdeplot(x=X_train_scaled['Age'], ax=ax2, label='Age')
sns.kdeplot(x=X_train_scaled['EstimatedSalary'], ax=ax2, label='EstimatedSalary')
ax2.legend()

plt.show()

# %% [markdown]
# Comparison of Distributions

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))
#befor scaling
ax1.set_title("Age Distribution Before Scaling")
sns.kdeplot(x=X_train['Age'], ax=ax1)
 
# after scaling
ax2.set_title("Age Distribution After Scaling")
sns.kdeplot(x=X_train_scaled['Age'], ax=ax2)
plt.show()

# %% [markdown]
# Logistic Regression Algorithm

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# without  Scaling
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)  
print("ActualData: ",accuracy_score(y_test,y_pred))
# Out:
# ActualData:  0.89

# %%
# With Scaling
lr_scaled=LogisticRegression()
lr_scaled.fit(X_train_scaled,y_train)
y_pred_scaled=lr_scaled.predict(X_test_scaled)  

print("ScaledData: ",accuracy_score(y_test,y_pred_scaled))
# Out:
# ScaledData:  0.89

# %% [markdown]
# Decision Tree  Algorithm

# %%
from sklearn.tree  import  DecisionTreeClassifier

# %%
dc= DecisionTreeClassifier()
dc.fit(X_train,y_train)
y_pred_dc=dc.predict(X_test)
print("Decision Tree Actual: ",accuracy_score(y_test,y_pred_dc))
# Out:
# Decision Tree Actual:  0.91

# %%
dc_scaled= DecisionTreeClassifier()
dc_scaled.fit(X_train_scaled,y_train)
y_pred_dc_scaled=dc_scaled.predict(X_test_scaled)
print("Decision Tree Scaled: ",accuracy_score(y_test,y_pred_dc_scaled))
# Out:
# Decision Tree Scaled:  0.91

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.581649        -0.886707
# 1   -0.606738         1.461738
# 2   -0.012544        -0.567782
# 3   -0.606738         1.896635
# 4    1.373907        -1.408584
# ..        ...              ...
# 295  0.977778        -1.147645
# 296 -0.903834        -0.770734
# 297 -0.210609        -0.509796
# 298 -1.101899        -0.451810
# 299 -1.200931         1.403751
#
# [300 rows x 2 columns]

# %% [markdown]
# Random Forest  Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred_rf=rf.predict(X_test)
print("Random Forest Actual: ",accuracy_score(y_test,y_pred_rf))
# Out:
# Random Forest Actual:  0.92

# %%
rf_scaled= RandomForestClassifier()
rf_scaled.fit(X_train_scaled,y_train)   
y_pred_rf_scaled=rf_scaled.predict(X_test_scaled)
print("Random Forest Scaled: ",accuracy_score(y_test,y_pred_rf_scaled))
# Out:
# Random Forest Scaled:  0.91

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000
